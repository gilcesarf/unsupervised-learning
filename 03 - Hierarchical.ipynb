# %% [markdown]
# # Clusterização Hierárquica
#
# ## 1. Introdução
#
# Neste notebook, exploraremos os algoritmos de clusterização hierárquica, uma família de métodos que constrói uma hierarquia de clusters organizando os dados em uma estrutura semelhante a uma árvore. Diferentemente do K-Means, que requer que especifiquemos o número de clusters antecipadamente, a clusterização hierárquica nos permite descobrir a estrutura natural dos dados em diferentes níveis de granularidade.
#
# A clusterização hierárquica pode ser dividida em duas abordagens principais:
# - **Aglomerativa (Bottom-up)**: Inicia com cada ponto como um cluster individual e, iterativamente, combina os clusters mais próximos até formar um único cluster.
# - **Divisiva (Top-down)**: Inicia com todos os pontos em um único cluster e, recursivamente, divide os clusters até que cada ponto forme seu próprio cluster.
#
# ### Conteúdos abordados:
#
# * **Fundamentação Matemática**: Métricas de distância entre clusters e critérios de ligação.
# * **Implementação em Python**: Construção do algoritmo aglomerativo passo a passo usando NumPy.
# * **Dendrogramas**: Visualização da hierarquia de clusters.
# * **Critérios de Ligação**: Single, Complete, Average e Ward.
# * **Determinação do Número de Clusters**: Métodos para "cortar" o dendrograma.
# * **Aplicações Práticas**: Análise de dados reais e comparação com K-Means.

# %%
# Célula de importação de bibliotecas

import numpy as np
import matplotlib.pyplot as plt
from sklearn.datasets import load_iris, load_wine
from scipy.cluster.hierarchy import dendrogram, linkage
import pandas as pd
import seaborn as sns

# Estilo para os gráficos
plt.style.use('seaborn-v0_8-whitegrid')
# %matplotlib inline

# %% [markdown]
# ## 2. Fundamentação Matemática da Clusterização Hierárquica
#
# A clusterização hierárquica aglomerativa funciona com base em uma **matriz de distâncias** entre todos os pares de pontos (ou clusters). O algoritmo segue estes passos fundamentais:
#
# 1. **Inicialização**: Cada observação $\mathbf{x}_i$ forma um cluster individual $C_i = \{\mathbf{x}_i\}$.
#
# 2. **Cálculo da Matriz de Distâncias**: Para $N$ pontos, calculamos uma matriz simétrica $D \in \mathbb{R}^{N \times N}$ onde $D_{ij}$ representa a distância entre os pontos $\mathbf{x}_i$ e $\mathbf{x}_j$:
#    $$ D_{ij} = d(\mathbf{x}_i, \mathbf{x}_j) $$
#
# 3. **Iteração**: Em cada passo, encontramos o par de clusters $(C_i, C_j)$ com menor distância e os combinamos em um novo cluster $C_{ij} = C_i \cup C_j$.
#
# 4. **Atualização**: Recalculamos as distâncias do novo cluster para todos os outros clusters existentes.
#
# 5. **Terminação**: O processo continua até que reste apenas um cluster contendo todas as observações.

# %% [markdown]
# ### Critérios de Ligação (Linkage)
#
# O ponto crucial da clusterização hierárquica é como definimos a distância entre dois clusters. Existem vários critérios de ligação:
#
# 1. **Single Linkage (Ligação Simples)**:
#    $$ d(C_i, C_j) = \min_{\mathbf{x} \in C_i, \mathbf{y} \in C_j} d(\mathbf{x}, \mathbf{y}) $$
#    A distância é definida pelos pontos mais próximos entre os clusters.
#
# 2. **Complete Linkage (Ligação Completa)**:
#    $$ d(C_i, C_j) = \max_{\mathbf{x} \in C_i, \mathbf{y} \in C_j} d(\mathbf{x}, \mathbf{y}) $$
#    A distância é definida pelos pontos mais distantes entre os clusters.
#
# 3. **Average Linkage (Ligação Média)**:
#    $$ d(C_i, C_j) = \frac{1}{|C_i||C_j|} \sum_{\mathbf{x} \in C_i} \sum_{\mathbf{y} \in C_j} d(\mathbf{x}, \mathbf{y}) $$
#    A distância é a média de todas as distâncias entre pares de pontos dos clusters.
#
# 4. **Ward Linkage (Critério de Ward)**:
#    $$d(C_i, C_j) = \frac{|C_i||C_j|}{|C_i|+|C_j|} \|\mathbf{m}_i - \mathbf{m}_j\|^2$$
#    Onde $\mathbf{m}_i$ e $\mathbf{m}_j$ são os centróides dos clusters $C_i$ e $C_j$, respectivamente, e $|C_k|$ é o número de pontos no cluster $C_k$.
#    Minimiza a variância intra-cluster ao combinar clusters. É baseado na soma dos quadrados das distâncias aos centróides.

# %% [markdown]
# ## 3. Preparação dos Dados
#
# Vamos começar com um exemplo simples usando dados sintéticos para entender visualmente como funciona a clusterização hierárquica. Depois, aplicaremos o algoritmo ao dataset Iris.

# %%
# Gerando dados sintéticos simples para demonstração
np.random.seed(42)
X_simple = np.array([[1, 2], [1.5, 1.8], [5, 8], [8, 8], [1, 0.6], [9, 11]])

# Visualizar os dados
plt.figure(figsize=(8, 6))
plt.scatter(X_simple[:, 0], X_simple[:, 1], c='blue', s=100, alpha=0.7)
for i, (x, y) in enumerate(X_simple):
    plt.annotate(f'P{i}', (x, y), xytext=(5, 5), textcoords='offset points')
plt.title('Dataset Simples para Demonstração')
plt.xlabel('Feature 1')
plt.ylabel('Feature 2')
plt.grid(True)
plt.show()

print(f"Coordenadas dos pontos:")
for i, point in enumerate(X_simple):
    print(f"P{i}: {point}")
# Out:
# Coordenadas dos pontos:
# P0: [1. 2.]
# P1: [1.5 1.8]
# P2: [5. 8.]
# P3: [8. 8.]
# P4: [1.  0.6]
# P5: [ 9. 11.]

# %% [markdown]
# ## 4. Implementação do Algoritmo Hierárquico Aglomerativo
#
# Vamos construir uma implementação simplificada do algoritmo hierárquico aglomerativo para entender seus passos fundamentais.

# %%
class HierarchicalClustering:
    def __init__(self, linkage='single'):
        """
        Inicializa o algoritmo de clusterização hierárquica.
        
        Parameters:
        linkage: str, critério de ligação ('single', 'complete', 'average')
        """
        self.linkage = linkage
        self.merge_history = []
        self.distances = []
        
    def _calculate_distance_matrix(self, X):
        """
        Calcula a matriz de distâncias entre todos os pares de pontos.
        """
        n = len(X)
        dist_matrix = np.zeros((n, n))
        
        for i in range(n):
            for j in range(i+1, n):
                dist = np.linalg.norm(X[i] - X[j])
                dist_matrix[i, j] = dist
                dist_matrix[j, i] = dist
                
        return dist_matrix
    
    def _cluster_distance(self, cluster1, cluster2, X, dist_matrix):
        """
        Calcula a distância entre dois clusters baseado no critério de ligação.
        """
        if self.linkage == 'single':
            # Distância mínima entre qualquer par de pontos dos clusters
            min_dist = float('inf')
            for i in cluster1:
                for j in cluster2:
                    if dist_matrix[i, j] < min_dist:
                        min_dist = dist_matrix[i, j]
            return min_dist
            
        elif self.linkage == 'complete':
            # Distância máxima entre qualquer par de pontos dos clusters
            max_dist = 0
            for i in cluster1:
                for j in cluster2:
                    if dist_matrix[i, j] > max_dist:
                        max_dist = dist_matrix[i, j]
            return max_dist
            
        elif self.linkage == 'average':
            # Distância média entre todos os pares de pontos dos clusters
            # Completado como resposta do exercício 1
            total_dist = 0
            total_pairs = 0
            for i in cluster1:
                for j in cluster2:
                    total_dist += dist_matrix[i, j]
                    total_pairs += 1
            return total_dist / total_pairs

    def fit(self, X):
        """
        Executa o algoritmo de clusterização hierárquica aglomerativa.
        """
        n = len(X)
        
        # Inicializar cada ponto como um cluster
        clusters = [[i] for i in range(n)]
        
        # Calcular matriz de distâncias inicial
        dist_matrix = self._calculate_distance_matrix(X)
        
        self.merge_history = []
        self.distances = []
        
        step = 0
        print(f"Passo inicial: {len(clusters)} clusters individuais")
        print(f"Clusters: {clusters}\n")
        
        # Continuar até que reste apenas um cluster
        while len(clusters) > 1:
            # Encontrar o par de clusters mais próximo
            min_distance = float('inf')
            merge_i, merge_j = -1, -1
            
            for i in range(len(clusters)):
                for j in range(i+1, len(clusters)):
                    distance = self._cluster_distance(clusters[i], clusters[j], X, dist_matrix)
                    if distance < min_distance:
                        min_distance = distance
                        merge_i, merge_j = i, j
            
            # Combinar os clusters mais próximos
            new_cluster = clusters[merge_i] + clusters[merge_j]
            
            # Salvar informações da fusão
            self.merge_history.append((clusters[merge_i].copy(), clusters[merge_j].copy()))
            self.distances.append(min_distance)
            
            step += 1
            print(f"Passo {step}: Combinar clusters {clusters[merge_i]} e {clusters[merge_j]}")
            print(f"Distância: {min_distance:.3f}")
            
            # Remover os clusters antigos e adicionar o novo
            clusters = [clusters[k] for k in range(len(clusters)) if k != merge_i and k != merge_j]
            clusters.append(new_cluster)
            
            print(f"Clusters restantes: {clusters}\n")

# %% [markdown]
# ## 5. Executando o Algoritmo no Dataset Simples
#
# Vamos aplicar nossa implementação nos dados simples para observar passo a passo como os clusters são formados.

# %%
# Executar a clusterização hierárquica com ligação simples
hc_single = HierarchicalClustering(linkage='single')
hc_single.fit(X_simple)
# Out:
# Passo inicial: 6 clusters individuais
# Clusters: [[0], [1], [2], [3], [4], [5]]
#
# Passo 1: Combinar clusters [0] e [1]
# Distância: 0.539
# Clusters restantes: [[2], [3], [4], [5], [0, 1]]
#
# Passo 2: Combinar clusters [4] e [0, 1]
# Distância: 1.300
# Clusters restantes: [[2], [3], [5], [4, 0, 1]]
#
# Passo 3: Combinar clusters [2] e [3]
# Distância: 3.000
# Clusters restantes: [[5], [4, 0, 1], [2, 3]]
#
# Passo 4: Combinar clusters [5] e [2, 3]
# Distância: 3.162
# Clusters restantes: [[4, 0, 1], [5, 2, 3]]
#
# Passo 5: Combinar clusters [4, 0, 1] e [5, 2, 3]
# Distância: 7.120
# Clusters restantes: [[4, 0, 1, 5, 2, 3]]

# %% [markdown]
# ## 6. Dendrogramas: Visualizando a Hierarquia
#
# Um **dendrograma** é a representação gráfica da hierarquia de clusters. É uma estrutura em forma de árvore que mostra a ordem e as distâncias nas quais os clusters foram combinados.
#
# ### Interpretação do Dendrograma:
# - **Eixo horizontal**: Representa as observações ou clusters.
# - **Eixo vertical**: Representa a distância na qual os clusters foram unidos.
# - **Altura dos ramos**: Indica a dissimilaridade entre os clusters combinados.
#
# Vamos usar a implementação otimizada do SciPy para criar dendrogramas profissionais:

# %% [markdown]
# ### Usando as Funções `linkage` e `fcluster` do SciPy
#
# O SciPy fornece funções otimizadas para clusterização hierárquica que são muito mais eficientes que nossa implementação educacional. As duas funções principais são:
#
# #### 1. Função `linkage(X, method)`
#
# A função `linkage` calcula a matriz de ligação que representa a hierarquia de clusters:
#
# ```python
# from scipy.cluster.hierarchy import linkage
#
# # Sintaxe básica
# linkage_matrix = linkage(X, method='ward')
# ```
#
# **Parâmetros principais:**
# - `X`: matriz de dados (n_samples × n_features)
# - `method`: critério de ligação ('single', 'complete', 'average', 'ward')
# - `metric`: métrica de distância (padrão: 'euclidean')
#
# **Retorno:**
# - Matriz (n-1) × 4 onde cada linha representa uma fusão:
#   - Colunas 0 e 1: índices dos clusters sendo combinados
#   - Coluna 2: distância da fusão
#   - Coluna 3: número de observações no novo cluster
#
# #### 2. Função `fcluster(Z, t, criterion)`
#
# A função `fcluster` extrai clusters da matriz de ligação com base em um critério de corte:
#
# ```python
# from scipy.cluster.hierarchy import fcluster
#
# # Obter clusters com base na distância
# clusters = fcluster(linkage_matrix, t=3.0, criterion='distance')
#
# # Obter um número específico de clusters
# clusters = fcluster(linkage_matrix, t=3, criterion='maxclust')
# ```
#
# **Parâmetros principais:**
# - `Z`: matriz de ligação (resultado de `linkage`)
# - `t`: valor do critério de corte
# - `criterion`: tipo de critério ('distance', 'maxclust', 'inconsistent')
#
# **Critérios de corte:**
# - `'distance'`: corta em uma altura específica do dendrograma
# - `'maxclust'`: força um número específico de clusters
# - `'inconsistent'`: baseado no coeficiente de inconsistência

# %%
# Usando scipy para criar dendrogramas profissionais
# Diferentes critérios de ligação

linkage_methods = ['single', 'complete', 'average', 'ward']

fig, axes = plt.subplots(2, 2, figsize=(15, 10))
axes = axes.ravel()

for i, method in enumerate(linkage_methods):
    # Calcular a matriz de ligação
    linkage_matrix = linkage(X_simple, method=method)
    
    # Criar o dendrograma
    dendrogram(linkage_matrix, ax=axes[i], labels=[f'P{j}' for j in range(len(X_simple))])
    axes[i].set_title(f'Dendrograma - {method.capitalize()} Linkage')
    axes[i].set_xlabel('Pontos de Dados')
    axes[i].set_ylabel('Distância')

plt.tight_layout()
plt.show()

# %% [markdown]
# ### Comparação dos Critérios de Ligação
#
# Cada critério de ligação produz diferentes estruturas de cluster:
#
# - **Single Linkage**: Tende a criar clusters elongados e pode sofrer do "efeito corrente" (chaining effect).
# - **Complete Linkage**: Produz clusters mais compactos e esféricos.
# - **Average Linkage**: Um meio-termo entre single e complete.
# - **Ward Linkage**: Minimiza a variância intra-cluster, similar ao objetivo do K-Means.

# %% [markdown]
# ## 7. Determinando o Número de Clusters
#
# Uma das grandes vantagens da clusterização hierárquica é que podemos "cortar" o dendrograma em diferentes alturas para obter diferentes números de clusters. Isso é feito traçando uma linha horizontal através do dendrograma.

# %%
# Usar Ward linkage para o exemplo
linkage_matrix = linkage(X_simple, method='ward')

# Definir diferentes alturas de corte
cut_heights = [2.0, 4.0, 6.0]
colors = ['red', 'green', 'blue']

# Visualizar o dendrograma com diferentes cortes
plt.figure(figsize=(10, 6))
dendrogram(linkage_matrix, labels=[f'P{j}' for j in range(len(X_simple))])

for height, color in zip(cut_heights, colors):
    plt.axhline(y=height, color=color, linestyle='--', label=f'Corte em {height}')

plt.title('Dendrograma com Linhas de Corte')
plt.xlabel('Pontos de Dados')
plt.ylabel('Distância')
plt.legend()
plt.show()

# %%
# Predição de clusters baseada em diferentes linhas de corte
from scipy.cluster.hierarchy import fcluster

print("Predição de clusters para diferentes alturas de corte:")
print("=" * 55)

for i, height in enumerate(cut_heights):
    # Obter clusters para a altura de corte específica
    clusters = fcluster(linkage_matrix, height, criterion='distance')
    n_clusters = len(np.unique(clusters))
    
    print()
    print(f"Altura de corte: {height}")
    print(f"Número de clusters: {n_clusters}")
    
    # Mostrar quais pontos pertencem a cada cluster
    for cluster_id in np.unique(clusters):
        points = [f"P{j}" for j in range(len(X_simple)) if clusters[j] == cluster_id]
        print(f"  Cluster {cluster_id}: {points}")
# Out:
# Predição de clusters para diferentes alturas de corte:
# =======================================================
#
# Altura de corte: 2.0
# Número de clusters: 4
#   Cluster 1: ['P0', 'P1', 'P4']
#   Cluster 2: ['P2']
#   Cluster 3: ['P3']
#   Cluster 4: ['P5']
#
# Altura de corte: 4.0
# Número de clusters: 3
#   Cluster 1: ['P0', 'P1', 'P4']
#   Cluster 2: ['P2', 'P3']
#   Cluster 3: ['P5']
#
# Altura de corte: 6.0
# Número de clusters: 2
#   Cluster 1: ['P0', 'P1', 'P4']
#   Cluster 2: ['P2', 'P3', 'P5']

# %%
# Visualização dos clusters resultantes
fig, axes = plt.subplots(1, len(cut_heights), figsize=(15, 4))

for i, height in enumerate(cut_heights):
    clusters = fcluster(linkage_matrix, height, criterion='distance')
    scatter = axes[i].scatter(X_simple[:, 0], X_simple[:, 1], c=clusters, s=100, alpha=0.7, cmap='viridis')
    
    # Adicionar rótulos dos pontos
    for j, (x, y) in enumerate(X_simple):
        axes[i].annotate(f'P{j}', (x, y), xytext=(5, 5), textcoords='offset points')
    
    axes[i].set_title(f'Clusters (corte = {height})\n{len(np.unique(clusters))} clusters')
    axes[i].set_xlabel('Feature 1')
    axes[i].set_ylabel('Feature 2')
    axes[i].grid(True)

plt.tight_layout()
plt.show()

# %% [markdown]
# ## 8. Aplicação ao Dataset Iris
#
# Agora vamos aplicar a clusterização hierárquica ao dataset Iris e comparar os resultados com o K-Means.

# %%
# Carregar o dataset Iris
iris = load_iris()
X_iris = iris.data[:, 2:]  # Usar comprimento e largura da pétala
y_true = iris.target

# Aplicar diferentes métodos de ligação
methods = ['ward', 'complete', 'average', 'single']

fig, axes = plt.subplots(2, 4, figsize=(20, 10))

for i, method in enumerate(methods):
    # Calcular a matriz de ligação
    linkage_matrix = linkage(X_iris, method=method)
    
    # Dendrograma
    dendrogram(linkage_matrix, ax=axes[0, i], no_labels=True)
    axes[0, i].set_title(f'Dendrograma - {method.capitalize()}')
    
    # Obter 3 clusters
    clusters = fcluster(linkage_matrix, 3, criterion='maxclust')
    
    # Plotar os clusters
    scatter = axes[1, i].scatter(X_iris[:, 0], X_iris[:, 1], c=clusters, s=50, alpha=0.7, cmap='viridis')
    axes[1, i].set_title(f'Clusters - {method.capitalize()}')
    axes[1, i].set_xlabel('Comprimento da Pétala')
    axes[1, i].set_ylabel('Largura da Pétala')
    
plt.tight_layout()
plt.show()

# %% [markdown]
# ### Avaliação dos Resultados
#
# Vamos calcular a taxa de acertos para cada método de ligação:

# %%
from scipy.stats import mode

def calculate_purity(y_true, y_pred):
    """
    Calcula a pureza dos clusters comparando com os rótulos verdadeiros.
    """
    correct_predictions = 0
    n_samples = len(y_true)
    
    for cluster_id in np.unique(y_pred):
        mask = (y_pred == cluster_id)
        if np.sum(mask) > 0:
            dominant_label = mode(y_true[mask], keepdims=True)[0][0]
            correct_predictions += np.sum(y_true[mask] == dominant_label)
    
    return correct_predictions / n_samples

print("Comparação dos métodos de ligação no dataset Iris:")
print("="*50)

for method in methods:
    linkage_matrix = linkage(X_iris, method=method)
    clusters = fcluster(linkage_matrix, 3, criterion='maxclust')
    purity = calculate_purity(y_true, clusters)
    print(f"{method.capitalize():12} Linkage: {purity:.1%} de acertos")
# Out:
# Comparação dos métodos de ligação no dataset Iris:
# ==================================================
# Ward         Linkage: 96.0% de acertos
# Complete     Linkage: 96.0% de acertos
# Average      Linkage: 96.0% de acertos
# Single       Linkage: 67.3% de acertos

# %% [markdown]
# ### Exercício 1: Implementação do Average Linkage
#
# Complete a implementação da nossa classe `HierarchicalClustering` adicionando o método **Average Linkage**. Em seguida, teste todos os três métodos de ligação (single, complete, average) no dataset simples (`X_simple`) e compare os resultados.

# %% [markdown]
# #### Implementacao do metodo de calculo de distancia para a classe HierarchicalClustering

# %%
class HierarchicalClusteringSolution:
    def __init__(self, linkage='single'):
        """
        Inicializa o algoritmo de clusterização hierárquica.
        
        Parameters:
        linkage: str, critério de ligação ('single', 'complete', 'average')
        """
        self.linkage = linkage
        self.merge_history = []
        self.distances = []
        
    def _calculate_distance_matrix(self, X):
        """
        Calcula a matriz de distâncias entre todos os pares de pontos.
        """
        n = len(X)
        dist_matrix = np.zeros((n, n))
        
        for i in range(n):
            for j in range(i+1, n):
                dist = np.linalg.norm(X[i] - X[j])
                dist_matrix[i, j] = dist
                dist_matrix[j, i] = dist
                
        return dist_matrix
    
    def _cluster_distance(self, cluster1, cluster2, X, dist_matrix):
        """
        Calcula a distância entre dois clusters baseado no critério de ligação.
        """
        if self.linkage == 'single':
            # Distância mínima entre qualquer par de pontos dos clusters
            min_dist = float('inf')
            for i in cluster1:
                for j in cluster2:
                    if dist_matrix[i, j] < min_dist:
                        min_dist = dist_matrix[i, j]
            return min_dist
            
        elif self.linkage == 'complete':
            # Distância máxima entre qualquer par de pontos dos clusters
            max_dist = 0
            for i in cluster1:
                for j in cluster2:
                    if dist_matrix[i, j] > max_dist:
                        max_dist = dist_matrix[i, j]
            return max_dist
            
        elif self.linkage == 'average':
            # Distância média entre todos os pares de pontos dos clusters
            # Completado como resposta do exercício 1
            total_dist = 0
            total_pairs = 0
            for i in cluster1:
                for j in cluster2:
                    total_dist += dist_matrix[i, j]
                    total_pairs += 1
            return total_dist / total_pairs
        elif self.linkage == 'ward':
            # Distância Ward: minimiza a soma das distâncias quadradas intra-cluster
            # Extra: Implementação do método Ward
            n1 = len(cluster1)
            n2 = len(cluster2)
            n = n1 + n2
            return np.sqrt((n1 * n2) / n) * np.linalg.norm(np.mean(X[cluster1]) - np.mean(X[cluster2]))

    def fit(self, X):
        """
        Executa o algoritmo de clusterização hierárquica aglomerativa.
        """
        n = len(X)
        
        # Inicializar cada ponto como um cluster
        clusters = [[i] for i in range(n)]
        
        # Calcular matriz de distâncias inicial
        dist_matrix = self._calculate_distance_matrix(X)
        
        self.merge_history = []
        self.distances = []
        
        step = 0
        print(f"Passo inicial: {len(clusters)} clusters individuais")
        print(f"Clusters: {clusters}\n")
        
        # Continuar até que reste apenas um cluster
        while len(clusters) > 1:
            # Encontrar o par de clusters mais próximo
            min_distance = float('inf')
            merge_i, merge_j = -1, -1
            
            for i in range(len(clusters)):
                for j in range(i+1, len(clusters)):
                    distance = self._cluster_distance(clusters[i], clusters[j], X, dist_matrix)
                    if distance < min_distance:
                        min_distance = distance
                        merge_i, merge_j = i, j
            
            # Combinar os clusters mais próximos
            new_cluster = clusters[merge_i] + clusters[merge_j]
            
            # Salvar informações da fusão
            self.merge_history.append((clusters[merge_i].copy(), clusters[merge_j].copy()))
            self.distances.append(min_distance)
            
            step += 1
            print(f"Passo {step}: Combinar clusters {clusters[merge_i]} e {clusters[merge_j]}")
            print(f"Distância: {min_distance:.3f}")
            
            # Remover os clusters antigos e adicionar o novo
            clusters = [clusters[k] for k in range(len(clusters)) if k != merge_i and k != merge_j]
            clusters.append(new_cluster)
            
            print(f"Clusters restantes: {clusters}\n")

    def linkage_matrix(self):
        """
        Retorna a linkage_matrix correspondente à solução de clusterização hierárquica.
        """
        import numpy as np

        n = len(self.merge_history) + 1
        linkage_matrix = []
        clusters = {i: [i] for i in range(n)}
        next_cluster_id = n

        for (c1, c2), dist in zip(self.merge_history, self.distances):
            id1 = [k for k, v in clusters.items() if sorted(v) == sorted(c1)][0]
            id2 = [k for k, v in clusters.items() if sorted(v) == sorted(c2)][0]
            tam = len(clusters[id1]) + len(clusters[id2])
            linkage_matrix.append([id1, id2, dist, tam])
            clusters[next_cluster_id] = clusters[id1] + clusters[id2]
            del clusters[id1]
            del clusters[id2]
            next_cluster_id += 1

        return np.array(linkage_matrix)

# %% [markdown]
# #### Teste da classe

# %%
# Teste da classe de clusterização hierárquica com o dataset X_simple já existente no notebook
# Comparação dos resultados para os três métodos de cálculo de distância, gerando o dendrograma para cada alternativa

linkage_methods = ['single', 'complete', 'average', 'ward']
cluster_solution = {}

for i, metodo in enumerate(linkage_methods):
    print(f"\n=== Método: {metodo} ===")
    # Instanciar e ajustar o algoritmo implementado
    hclust = HierarchicalClusteringSolution(linkage=metodo)
    hclust.fit(X_simple)

    cluster_solution[metodo] = hclust

    # Exibir o histórico de fusão
    print(f"Histórico de fusão (implementação própria) com método: {metodo}:")
    for idx, (c1, c2) in enumerate(hclust.merge_history):
        print(f"Passo {idx+1}: {c1} + {c2} -> distância: {hclust.distances[idx]:.3f}")
# Out:
# === Método: single ===
# Passo inicial: 6 clusters individuais
# Clusters: [[0], [1], [2], [3], [4], [5]]
#
# Passo 1: Combinar clusters [0] e [1]
# Distância: 0.539
# Clusters restantes: [[2], [3], [4], [5], [0, 1]]
#
# Passo 2: Combinar clusters [4] e [0, 1]
# Distância: 1.300
# Clusters restantes: [[2], [3], [5], [4, 0, 1]]
#
# Passo 3: Combinar clusters [2] e [3]
# Distância: 3.000
# Clusters restantes: [[5], [4, 0, 1], [2, 3]]
#
# Passo 4: Combinar clusters [5] e [2, 3]
# Distância: 3.162
# Clusters restantes: [[4, 0, 1], [5, 2, 3]]
#
# Passo 5: Combinar clusters [4, 0, 1] e [5, 2, 3]
# Distância: 7.120
# Clusters restantes: [[4, 0, 1, 5, 2, 3]]
#
# Histórico de fusão (implementação própria) com método: single:
# Passo 1: [0] + [1] -> distância: 0.539
# Passo 2: [4] + [0, 1] -> distância: 1.300
# Passo 3: [2] + [3] -> distância: 3.000
# Passo 4: [5] + [2, 3] -> distância: 3.162
# Passo 5: [4, 0, 1] + [5, 2, 3] -> distância: 7.120
#
# === Método: complete ===
# Passo inicial: 6 clusters individuais
# Clusters: [[0], [1], [2], [3], [4], [5]]
#
# Passo 1: Combinar clusters [0] e [1]
# Distância: 0.539
# Clusters restantes: [[2], [3], [4], [5], [0, 1]]
#
# Passo 2: Combinar clusters [4] e [0, 1]
# Distância: 1.400
# Clusters restantes: [[2], [3], [5], [4, 0, 1]]
#
# Passo 3: Combinar clusters [2] e [3]
# Distância: 3.000
# Clusters restantes: [[5], [4, 0, 1], [2, 3]]
#
# Passo 4: Combinar clusters [5] e [2, 3]
# Distância: 5.000
# Clusters restantes: [[4, 0, 1], [5, 2, 3]]
#
# Passo 5: Combinar clusters [4, 0, 1] e [5, 2, 3]
# Distância: 13.121
# Clusters restantes: [[4, 0, 1, 5, 2, 3]]
#
# Histórico de fusão (implementação própria) com método: complete:
# Passo 1: [0] + [1] -> distância: 0.539
# Passo 2: [4] + [0, 1] -> distância: 1.400
# Passo 3: [2] + [3] -> distância: 3.000
# Passo 4: [5] + [2, 3] -> distância: 5.000
# Passo 5: [4, 0, 1] + [5, 2, 3] -> distância: 13.121
#
# === Método: average ===
# Passo inicial: 6 clusters individuais
# Clusters: [[0], [1], [2], [3], [4], [5]]
#
# Passo 1: Combinar clusters [0] e [1]
# Distância: 0.539
# Clusters restantes: [[2], [3], [4], [5], [0, 1]]
#
# Passo 2: Combinar clusters [4] e [0, 1]
# Distância: 1.350
# Clusters restantes: [[2], [3], [5], [4, 0, 1]]
#
# Passo 3: Combinar clusters [2] e [3]
# Distância: 3.000
# Clusters restantes: [[5], [4, 0, 1], [2, 3]]
#
# Passo 4: Combinar clusters [5] e [2, 3]
# Distância: 4.081
# Clusters restantes: [[4, 0, 1], [5, 2, 3]]
#
# Passo 5: Combinar clusters [4, 0, 1] e [5, 2, 3]
# Distância: 9.796
# Clusters restantes: [[4, 0, 1, 5, 2, 3]]
#
# Histórico de fusão (implementação própria) com método: average:
# Passo 1: [0] + [1] -> distância: 0.539
# Passo 2: [4] + [0, 1] -> distância: 1.350
# Passo 3: [2] + [3] -> distância: 3.000
# Passo 4: [5] + [2, 3] -> distância: 4.081
# Passo 5: [4, 0, 1] + [5, 2, 3] -> distância: 9.796
#
# === Método: ward ===
# Passo inicial: 6 clusters individuais
# Clusters: [[0], [1], [2], [3], [4], [5]]
#
# Passo 1: Combinar clusters [0] e [1]
# Distância: 0.106
# Clusters restantes: [[2], [3], [4], [5], [0, 1]]
#
# Passo 2: Combinar clusters [4] e [0, 1]
# Distância: 0.633
# Clusters restantes: [[2], [3], [5], [4, 0, 1]]
#
# Passo 3: Combinar clusters [2] e [3]
# Distância: 1.061
# Clusters restantes: [[5], [4, 0, 1], [2, 3]]
#
# Passo 4: Combinar clusters [5] e [2, 3]
# Distância: 2.245
# Clusters restantes: [[4, 0, 1], [5, 2, 3]]
#
# Passo 5: Combinar clusters [4, 0, 1] e [5, 2, 3]
# Distância: 8.390
# Clusters restantes: [[4, 0, 1, 5, 2, 3]]
#
# Histórico de fusão (implementação própria) com método: ward:
# Passo 1: [0] + [1] -> distância: 0.106
# Passo 2: [4] + [0, 1] -> distância: 0.633
# Passo 3: [2] + [3] -> distância: 1.061
# Passo 4: [5] + [2, 3] -> distância: 2.245
# Passo 5: [4, 0, 1] + [5, 2, 3] -> distância: 8.390

# %% [markdown]
# #### Comparação dos resultados

# %%
# Gera dendrogramas para cada método de ligação em subplots para comparação visual

fig, axes = plt.subplots(2, 4, figsize=(20, 10))

for i, method in enumerate(methods):
    solution = cluster_solution[method]
    # Calcular a matriz de ligação
    linkage_matrix = solution.linkage_matrix()
    # Dendrograma
    dendrogram(linkage_matrix, ax=axes[0, i], labels=[f'P{j}' for j in range(len(X_simple))])
    axes[0, i].set_title(f'Dendrograma - {method.capitalize()}')
    
    # Obter 3 clusters
    clusters = fcluster(linkage_matrix, 3, criterion='maxclust')
    
    # Plotar os clusters usando X_simple (não X_iris)
    scatter = axes[1, i].scatter(X_simple[:, 0], X_simple[:, 1], c=clusters, s=100, alpha=0.7, cmap='viridis')
    axes[1, i].set_title(f'Clusters - {method.capitalize()}')
    
    # Adicionar rótulos dos pontos
    for j, (x, y) in enumerate(X_simple):
        axes[1, i].annotate(f'P{j}', (x, y), xytext=(5, 5), textcoords='offset points')
    
plt.tight_layout()
plt.show()

# %% [markdown]
# Para o dataset X_simple, embora a clusterização tenha sido a mesma nos quatro casos, as alturas que representam a distancia entre os pontos são diferentes em cada metodo. Pode-se notar, por exemplo, no ramo marcado em verde (P5, P2, P3), de forma bem clara a diferença nas alturas das linhas, o que representa a diferença no calculo das distancias.

# %% [markdown]
# ### Exercício 2: Análise do Dataset Wine - Seleção de Features e Comparação de Métodos
#
# Aplique a clusterização hierárquica do SciPy ao dataset Wine. Primeiro, você deve selecionar um bom par de features para visualização bidimensional, depois comparar diferentes métodos de ligação.
#
# **Tarefas:**
# 1. Carregue o dataset Wine e explore suas features
# 2. Selecione as duas melhores features para visualização (analise correlações, variâncias, etc.)
# 3. Aplique os 4 métodos de ligação ('single', 'complete', 'average', 'ward') usando `scipy.cluster.hierarchy.linkage`
# 4. Crie dendrogramas para cada método
# 5. Determine visualmente qual método produz a melhor separação

# %% [markdown]
# #### Carregando o dataset Wine

# %%
# Carregando o dataset Wine
wine = load_wine()
X_wine = wine.data
y_wine = wine.target

print("Dataset Wine:")
print(f"Shape: {X_wine.shape}")
print(f"Features: {wine.feature_names}")
print(f"Classes: {wine.target_names}")
# Out:
# Dataset Wine:
# Shape: (178, 13)
# Features: ['alcohol', 'malic_acid', 'ash', 'alcalinity_of_ash', 'magnesium', 'total_phenols', 'flavanoids', 'nonflavanoid_phenols', 'proanthocyanins', 'color_intensity', 'hue', 'od280/od315_of_diluted_wines', 'proline']
# Classes: ['class_0' 'class_1' 'class_2']

# %% [markdown]
# #### Análise das features para seleção

# %%
# 2. Análise das features para seleção
# Seu código aqui
# Convertendo para DataFrame para facilitar a análise
df_wine = pd.DataFrame(X_wine, columns=wine.feature_names)

#Normalizando as features
df_wine_norm = df_wine.apply(lambda x: (x - x.min()) / (x.max() - x.min()))
# Calculando a variância de cada feature normalizada
variancias = df_wine_norm.var()

# Imprime as variâncias ordenadas de maior para menor
print("Variância das features normalizadas(ordenadas):")
print(variancias.sort_values(ascending=False))

# Calculando a matriz de correlação normalizada 
correlacoes = df_wine_norm.corr()
print("\nMatriz de correlação normalizada:")
print(correlacoes)

# Visualizando a matriz de correlação normalizada
plt.figure(figsize=(10,8))
plt.title("Matriz de Correlação das Features do Wine")
im = plt.imshow(correlacoes, cmap='coolwarm', vmin=-1, vmax=1)
plt.colorbar(im, fraction=0.05, pad=0.01)
plt.xticks(ticks=np.arange(len(df_wine.columns)), labels=df_wine.columns, rotation=90)
plt.yticks(ticks=np.arange(len(df_wine.columns)), labels=df_wine.columns)

# Adicionando os valores na matriz, exceto na diagonal principal
for i in range(correlacoes.shape[0]):
    for j in range(correlacoes.shape[1]):
        if i != j:
            plt.text(j, i, f"{correlacoes.iloc[i, j]:.2f}", ha='center', va='center', color='black', fontsize=8)

plt.tight_layout()
plt.show()

# Visualizando a distribuição de todas as features, 
# ordenadas pela variância normalizada (da maior para a menor)
features_ordenadas = variancias.sort_values(ascending=False).index.tolist()
print("\nFeatures ordenadas pela variância normalizada:")
print(features_ordenadas)
plt.figure(figsize=(8, 4*len(features_ordenadas)))
for i, feature in enumerate(features_ordenadas):
    plt.subplot(len(features_ordenadas), 1, i+1)
    for classe in np.unique(y_wine):
        plt.hist(df_wine[feature][y_wine==classe], alpha=0.5, label=f'Classe {classe}')
    plt.title(f'Distribuição: {feature}')
    plt.xlabel(feature)
    plt.ylabel('Frequência')
    plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Variância das features normalizadas(ordenadas):
# od280/od315_of_diluted_wines    0.067636
# nonflavanoid_phenols            0.055139
# proline                         0.050451
# malic_acid                      0.048744
# total_phenols                   0.046574
# alcohol                         0.045641
# flavanoids                      0.044407
# color_intensity                 0.039127
# hue                             0.034533
# proanthocyanins                 0.032600
# alcalinity_of_ash               0.029633
# magnesium                       0.024101
# ash                             0.021523
# dtype: float64
#
# Matriz de correlação normalizada:
#                                alcohol  malic_acid       ash  \
# alcohol                       1.000000    0.094397  0.211545
# malic_acid                    0.094397    1.000000  0.164045
# ash                           0.211545    0.164045  1.000000
# alcalinity_of_ash            -0.310235    0.288500  0.443367
# magnesium                     0.270798   -0.054575  0.286587
# total_phenols                 0.289101   -0.335167  0.128980
# flavanoids                    0.236815   -0.411007  0.115077
# nonflavanoid_phenols         -0.155929    0.292977  0.186230
# proanthocyanins               0.136698   -0.220746  0.009652
# color_intensity               0.546364    0.248985  0.258887
# hue                          -0.071747   -0.561296 -0.074667
# od280/od315_of_diluted_wines  0.072343   -0.368710  0.003911
# proline                       0.643720   -0.192011  0.223626
#
#                               alcalinity_of_ash  magnesium  total_phenols  \
# alcohol                               -0.310235   0.270798       0.289101
# malic_acid                             0.288500  -0.054575      -0.335167
# ash                                    0.443367   0.286587       0.128980
# alcalinity_of_ash                      1.000000  -0.083333      -0.321113
# magnesium                             -0.083333   1.000000       0.214401
# total_phenols                         -0.321113   0.214401       1.000000
# flavanoids                            -0.351370   0.195784       0.864564
# nonflavanoid_phenols                   0.361922  -0.256294      -0.449935
# proanthocyanins                       -0.197327   0.236441       0.612413
# color_intensity                        0.018732   0.199950      -0.055136
# hue                                   -0.273955   0.055398       0.433681
# od280/od315_of_diluted_wines          -0.276769   0.066004       0.699949
# proline                               -0.440597   0.393351       0.498115
#
#                               flavanoids  nonflavanoid_phenols  \
# alcohol                         0.236815             -0.155929
# malic_acid                     -0.411007              0.292977
# ash                             0.115077              0.186230
# alcalinity_of_ash              -0.351370              0.361922
# magnesium                       0.195784             -0.256294
# total_phenols                   0.864564             -0.449935
# flavanoids                      1.000000             -0.537900
# nonflavanoid_phenols           -0.537900              1.000000
# proanthocyanins                 0.652692             -0.365845
# color_intensity                -0.172379              0.139057
# hue                             0.543479             -0.262640
# od280/od315_of_diluted_wines    0.787194             -0.503270
# proline                         0.494193             -0.311385
#
#                               proanthocyanins  color_intensity       hue  \
# alcohol                              0.136698         0.546364 -0.071747
# malic_acid                          -0.220746         0.248985 -0.561296
# ash                                  0.009652         0.258887 -0.074667
# alcalinity_of_ash                   -0.197327         0.018732 -0.273955
# magnesium                            0.236441         0.199950  0.055398
# total_phenols                        0.612413        -0.055136  0.433681
# flavanoids                           0.652692        -0.172379  0.543479
# nonflavanoid_phenols                -0.365845         0.139057 -0.262640
# proanthocyanins                      1.000000        -0.025250  0.295544
# color_intensity                     -0.025250         1.000000 -0.521813
# hue                                  0.295544        -0.521813  1.000000
# od280/od315_of_diluted_wines         0.519067        -0.428815  0.565468
# proline                              0.330417         0.316100  0.236183
#
#                               od280/od315_of_diluted_wines   proline
# alcohol                                           0.072343  0.643720
# malic_acid                                       -0.368710 -0.192011
# ash                                               0.003911  0.223626
# alcalinity_of_ash                                -0.276769 -0.440597
# magnesium                                         0.066004  0.393351
# total_phenols                                     0.699949  0.498115
# flavanoids                                        0.787194  0.494193
# nonflavanoid_phenols                             -0.503270 -0.311385
# proanthocyanins                                   0.519067  0.330417
# color_intensity                                  -0.428815  0.316100
# hue                                               0.565468  0.236183
# od280/od315_of_diluted_wines                      1.000000  0.312761
# proline                                           0.312761  1.000000
# Features ordenadas pela variância normalizada:
# ['od280/od315_of_diluted_wines', 'nonflavanoid_phenols', 'proline', 'malic_acid', 'total_phenols', 'alcohol', 'flavanoids', 'color_intensity', 'hue', 'proanthocyanins', 'alcalinity_of_ash', 'magnesium', 'ash']

# %% [markdown]
# #### 2. Seleção das duas melhores features

# %%
# 3. Seleção das duas melhores features

# Capturando os nomes das duas features com maior variância normalizada

top1_feature = features_ordenadas[5]
top2_feature = features_ordenadas[6]

# Variância de 'proline' e 'magnesium' são as top2 features com maior variância
print(f"Top1 Variância {top1_feature}: {df_wine[top1_feature].var()}")
print(f"Top2 Variância {top2_feature}: {df_wine[top2_feature].var()}")

# Imprimindo a correlação normalizada entre top1 e top2 features
correlacao_pm = df_wine_norm[top1_feature].corr(df_wine_norm[top2_feature])
print(f"Correlação normalizada entre {top1_feature} e {top2_feature}: {correlacao_pm}")

# Gráfico de dispersão entre as duas top features
plt.figure(figsize=(8,6))
for classe in np.unique(y_wine):
    plt.scatter(df_wine_norm[top1_feature][y_wine==classe], df_wine_norm[top2_feature][y_wine==classe], label=f'Classe {classe}', alpha=0.7)
plt.xlabel(top1_feature)
plt.ylabel(top2_feature)
plt.title(f'Dispersão entre {top1_feature} e {top2_feature}')
plt.legend()
plt.tight_layout()
plt.show()
# Out:
# Top1 Variância alcohol: 0.6590623278105759
# Top2 Variância flavanoids: 0.997718672633784
# Correlação normalizada entre alcohol e flavanoids: 0.23681492790034586

# %%
# Imprimindo a variância das features normalizadas 'proline' e 'magnesium'
print(f"Variância de {top1_feature} (normalizada):", df_wine_norm[top1_feature].var())
print(f"Variância de {top2_feature}  (normalizada):", df_wine_norm[top2_feature].var())

# Imprimindo a correlação entre 'proline' e 'magnesium' normalizadas
correlacao_pm_norm = df_wine_norm[top1_feature].corr(df_wine_norm[top2_feature])
print(f"Correlação entre {top1_feature} e {top2_feature} (normalizadas):", correlacao_pm_norm)
# Out:
# Variância de alcohol (normalizada): 0.04564143544394568
# Variância de flavanoids  (normalizada): 0.044406998194457085
# Correlação entre alcohol e flavanoids (normalizadas): 0.23681492790034586

# %% [markdown]
# Em principio tentamos comparar as top2 features pela variancia apenas, mas o grafico de dispersão mostrou que os dados não ficaram bem separados.
# Então verificamos que deveriamos normalizar os dados para poder comparar, mas ainda assim o grafico não mostrou boa separação de grupos.
#
# Então passamos a avaliar possiveis candidatos na sequencia, onde encontramos que a combinação **alcohol X flavanoids** aparentemente gera uma boa separação das classes. Vamos seguir com esses dois elementos para avaliar.

# %% [markdown]
# #### Aplicação dos métodos de ligação e criação dos dendrogramas

# %%
# 4. Aplicação dos métodos de ligação e criação dos dendrogramas
# Aplicação dos quatro métodos de ligação e criação dos dendrogramas

#from scipy.cluster.hierarchy import linkage, dendrogram

metodos = ['single', 'complete', 'average', 'ward']
X = df_wine_norm[['alcohol', 'flavanoids']].values  # Usando as duas features escolhidas

plt.figure(figsize=(20,10))
for i, metodo in enumerate(metodos):
    plt.figure(figsize=(20, 10))
    Z = linkage(X, method=metodo)
    dendrogram(Z, color_threshold=None)
    plt.title(f'Dendrograma - Método: {metodo}')
    plt.xlabel('Amostras')
    plt.ylabel('Distância')
    plt.tight_layout()
plt.show()

# %% [markdown]
# #### 5. Análise visual e determinação do melhor método

# %% [markdown]
# * Metodo Single:
#
# **Características visuais:** típico “chaining effect” (efeito de encadeamento), onde clusters vão se juntando um a um em alturas muito baixas.
#
# **No gráfico:** não há cortes claros, praticamente todo mundo se conecta de forma gradual em distâncias pequenas (~0,35).
#
# **Problema:** clusters muito alongados e pouco interpretáveis.
#
# **Avaliação:** claramente o pior método para este dataset.
#
#
# * Metodo Complete:
#
# **Características visuais:** tende a formar clusters mais compactos, pois usa a maior distância entre pares.
#
# **No gráfico:** aparecem 3 grandes grupos bem separados em alturas próximas de 1,0–1,2.
#
# **Vantagem:** boa separação entre grupos, sem o problema de "encadeamento".
#
# **Avaliação:** é uma escolha melhor que single, mostrando separações relativamente nítidas.
#
# * Método Average:
#
# **Características visuais:** apresenta agrupamentos mais suaves, com alturas de fusão relativamente baixas (~0,8 no máximo).
#
# **No gráfico:** não há um "salto" claro entre clusters, os agrupamentos são mais graduais.
#
# **Problema:** pode misturar clusters antes de alcançar boas separações, o que dificulta a definição de cortes limpos.
#
# **Avaliação:** menos indicado para este dataset, pois os grupos ficam difusos.
#
# * Metodo Ward:
#
# **Características visuais:** forma blocos bem equilibrados, com fusões ocorrendo em alturas progressivamente maiores.
#
# **Vantagem:** minimiza a variância dentro dos clusters, resultando em grupos mais compactos e esféricos.
#
# **No gráfico:** observa-se dois grupos grandes e bem definidos, com separações claras em alturas maiores (~3,5–4).
#
# **Avaliação**: ideal quando se espera clusters compactos e aproximadamente balanceados.
#
#
# #### Comparação final
#
# - **1a escolha: Ward:** → melhor escolha: cria 2–3 clusters bem separados e compactos, o que se ajusta bem ao Iris (onde sabemos que existem 3 espécies).
#
# - **2a escolha: Complete:** → alternativa razoável: também gera divisões nítidas, embora menos balanceadas que Ward.
#
# - Descartados :
# **Average** → disperso demais, sem cortes claros.
# **Single → sofre de encadeamento, não é adequado.

# %% [markdown]
# ### Exercício 3: Determinação do Número Ótimo de Clusters
#
# Com base no melhor método de ligação identificado no Exercício 2, determine o número ótimo de clusters para o dataset Wine usando análise visual do dendrograma e validação com os rótulos verdadeiros.
#
# **Tarefas:**
# 1. Use o melhor método identificado no exercício anterior
# 2. Crie um dendrograma detalhado com linha de corte ajustável
# 3. Teste diferentes números de clusters (2, 3, 4, 5) usando `fcluster`
# 4. Para cada número de clusters, visualize os clusters no scatter plot
# 5. Determine o número ótimo de clusters justificando sua escolha

# %%
# Exercício 3: Determinação do Número Ótimo de Clusters

# 1. Usando o método 'ward' identificado como melhor no exercício anterior

# Usar as mesmas features selecionadas no exercício anterior
X_wine_selected = df_wine_norm[['alcohol', 'flavanoids']].values
y_wine_true = y_wine

print("Análise do número ótimo de clusters:")
print("=" * 40)

# 2. Criar dendrograma detalhado com linha de corte ajustável
plt.figure(figsize=(15, 8))
Z_wine = linkage(X_wine_selected, method='ward')
dendrogram(Z_wine, color_threshold=None)
plt.title('Dendrograma - Dataset Wine (Método: Ward)')
plt.xlabel('Amostras')
plt.ylabel('Distância')

# Adicionar linhas de corte para diferentes números de clusters
cut_heights = [1.0, 1.5, 2.0, 3.0]
colors = ['red', 'green', 'blue', 'orange']
for height, color in zip(cut_heights, colors):
    plt.axhline(y=height, color=color, linestyle='--', alpha=0.7, label=f'Corte h={height}')

plt.legend()
plt.tight_layout()
plt.show()

# 3. Testar diferentes números de clusters
n_clusters_to_test = [2, 3, 4, 5]

print("\nAnálise de diferentes números de clusters:")
print("-" * 50)

# Usar as mesmas features selecionadas para clusterização (alcohol e flavanoids)
# Gráficos scatter individuais (um por linha)
for n_clusters in n_clusters_to_test:
    # Gerar rótulos dos clusters
    clusters = fcluster(Z_wine, n_clusters, criterion='maxclust')
    
    # Visualizar clusters no scatter plot usando as features originais
    plt.figure(figsize=(8, 6))
    scatter = plt.scatter(X_wine_selected[:, 0], X_wine_selected[:, 1], c=clusters, s=50, alpha=0.7, cmap='viridis')
    plt.title(f'Wine - Ward: {n_clusters} clusters')
    plt.xlabel('Alcohol (normalizado)')
    plt.ylabel('Flavanoids (normalizado)')
    plt.show()
    
# 4. Gráfico do cotovelo (Elbow Method)
print("\nGráfico do Cotovelo:")
print("-" * 30)

# Calcular distâncias para diferentes números de clusters
distances = []
for n_clusters in range(1, 11):  # Testar de 1 a 10 clusters
    clusters = fcluster(Z_wine, n_clusters, criterion='maxclust')
    
    # Calcular inércia (soma das distâncias quadradas aos centróides)
    inertia = 0
    for cluster_id in np.unique(clusters):
        cluster_points = X_wine_selected[clusters == cluster_id]
        if len(cluster_points) > 0:
            centroid = np.mean(cluster_points, axis=0)
            inertia += np.sum((cluster_points - centroid) ** 2)
    
    distances.append(inertia)

# Plotar gráfico do cotovelo
plt.figure(figsize=(10, 6))
plt.plot(range(1, 11), distances, 'bo-', linewidth=2, markersize=8)
plt.xlabel('Número de Clusters')
plt.ylabel('Inércia (Soma das Distâncias Quadradas)')
plt.title('Método do Cotovelo - Determinação do Número Ótimo de Clusters')
plt.grid(True, alpha=0.3)

# Destacar o ponto do cotovelo (3 clusters)
plt.axvline(x=3, color='red', linestyle='--', alpha=0.7, label='Cotovelo sugerido (3 clusters)')
plt.legend()
plt.show()
# Testar especificamente 3 clusters (número sugerido pelo método do cotovelo)
clusters_3 = fcluster(Z_wine, 3, criterion='maxclust')

print(f"Distribuição dos clusters para 3 clusters:")
for cluster_id in np.unique(clusters_3):
    cluster_mask = (clusters_3 == cluster_id)
    print(f"  Cluster {cluster_id}: {np.sum(cluster_mask)} amostras")
# Out:
# Análise do número ótimo de clusters:
# ========================================
# Análise de diferentes números de clusters:
# --------------------------------------------------
# Gráfico do Cotovelo:
# ------------------------------
# Distribuição dos clusters para 3 clusters:
#   Cluster 1: 71 amostras
#   Cluster 2: 47 amostras
#   Cluster 3: 60 amostras

# %% [markdown]
# O gráfico do cotovelo mostra onde a redução da inércia começa a diminuir significativamente.
#
# O 'cotovelo' sugere o número ótimo de clusters (aproximadamente 3).
#
# Justificativa:
#
# Analisando o dendrograma e o método do cotovelo, o número ótimo de clusters para o dataset Wine é 3.
# Isso se deve a que:
# 1. O dendrograma mostra uma separação clara em 3 grupos principais
# 2. O gráfico do cotovelo indica uma redução significativa da inércia até 3 clusters
# 3. A visualização PCA mostra clusters bem definidos e separados para 3 clusters
# 4. A distribuição dos clusters é equilibrada e interpretável
